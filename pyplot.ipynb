# %% [markdown]
# # Overview of the ```matplotlib.pyplot``` Python package

# %% [markdown]
# ## 1. Introduction

# %% [markdown]
# This notebook contains in-depth explanations of three interesting plots from the ```matplotlib.pyplot``` Python package.

# %% [markdown]
# Python is an interpreted, interactive, object-oriented programming language<sup id="a1">[1](#f1)</sup>.

# %% [markdown]
# Matplotlib is a comprehensive library for creating static, animated, and interactive visualizations in Python<sup id="a1">[1](#f1)</sup>.

# %% [markdown]
# ```matplotlib.pyplot``` is a state-based interface to matplotlib. It provides a MATLAB-like way of plotting<sup id="a2">[2](#f2)</sup>.

# %% [markdown]
# ## 2.

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## 3. Explainations of Plots

# %% [markdown]
# ### 3.1

# %%
import numpy as np
import matplotlib.pyplot as plt

# Fixing random state for reproducibility
np.random.seed(19680801)

# some random data
x = np.random.randn(1000)
y = np.random.randn(1000)


np.histogram_bin_edges(x, bins="auto", range=None, weights=None)
plt.hist(x)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_15588/2839226690.py in <module>
#      11
#      12 np.histogram_bin_edges(x, bins="auto", range=None, weights=None)
# ---> 13 plt.hist(x, y)
#
# ~\anaconda3\lib\site-packages\matplotlib\pyplot.py in hist(x, bins, range, density, weights, cumulative, bottom, histtype, align, orientation, rwidth, log, color, label, stacked, data, **kwargs)
#    2851         orientation='vertical', rwidth=None, log=False, color=None,
#    2852         label=None, stacked=False, *, data=None, **kwargs):
# -> 2853     return gca().hist(
#    2854         x, bins=bins, range=range, density=density, weights=weights,
#    2855         cumulative=cumulative, bottom=bottom, histtype=histtype,
#
# ~\anaconda3\lib\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
#    1359     def inner(ax, *args, data=None, **kwargs):
#    1360         if data is None:
# -> 1361             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1362
#    1363         bound = new_sig.bind(ax, *args, **kwargs)
#
# ~\anaconda3\lib\site-packages\matplotlib\axes\_axes.py in hist(self, x, bins, range, density, weights, cumulative, bottom, histtype, align, orientation, rwidth, log, color, label, stacked, **kwargs)
#    6757             # this will automatically overwrite bins,
#    6758             # so that each histogram uses the same bins
# -> 6759             m, bins = np.histogram(x[i], bins, weights=w[i], **hist_kwargs)
#    6760             tops.append(m)
#    6761         tops = np.array(tops, float)  # causes problems later if it's an int
#
# <__array_function__ internals> in histogram(*args, **kwargs)
#
# ~\anaconda3\lib\site-packages\numpy\lib\histograms.py in histogram(a, bins, range, normed, weights, density)
#     790     a, weights = _ravel_and_check_weights(a, weights)
#     791
# --> 792     bin_edges, uniform_bins = _get_bin_edges(a, bins, range, weights)
#     793
#     794     # Histogram is an integer or a float array depending on the weights.
#
# ~\anaconda3\lib\site-packages\numpy\lib\histograms.py in _get_bin_edges(a, bins, range, weights)
#     429         bin_edges = np.asarray(bins)
#     430         if np.any(bin_edges[:-1] > bin_edges[1:]):
# --> 431             raise ValueError(
#     432                 '`bins` must increase monotonically, when an array')
#     433
#
# ValueError: `bins` must increase monotonically, when an array

# %%
# definitions for the axes
left, width = 0.1, 0.65
bottom, height = 0.1, 0.65
spacing = 0.005


rect_scatter = [left, bottom, width, height]
rect_histx = [left, bottom + height + spacing, width, 0.2]
rect_histy = [left + width + spacing, bottom, 0.2, height]

# start with a square Figure
fig = plt.figure(figsize=(8, 8))

ax = fig.add_axes(rect_scatter)
ax_histx = fig.add_axes(rect_histx, sharex=ax)
ax_histy = fig.add_axes(rect_histy, sharey=ax)

# use the previously defined function
scatter_hist(x, y, ax, ax_histx, ax_histy)

plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_15588/3634468299.py in <module>
#      17
#      18 # use the previously defined function
# ---> 19 scatter_hist(x, y, ax, ax_histx, ax_histy)
#      20
#      21 plt.show()
#
# ~\AppData\Local\Temp/ipykernel_15588/3862433627.py in scatter_hist(x, y, ax, ax_histx, ax_histy)
#      20     # now determine nice limits by hand:
#      21     binwidth = 0.25
# ---> 22     np.histogram_bin_edges(x, bins='auto', range=(x, y))
#      23     #xymax = max(np.max(np.abs(x)), np.max(np.abs(y)))
#      24     #lim = (int(xymax/binwidth) + 1) * binwidth
#
# <__array_function__ internals> in histogram_bin_edges(*args, **kwargs)
#
# ~\anaconda3\lib\site-packages\numpy\lib\histograms.py in histogram_bin_edges(a, bins, range, weights)
#     666     """
#     667     a, weights = _ravel_and_check_weights(a, weights)
# --> 668     bin_edges, _ = _get_bin_edges(a, bins, range, weights)
#     669     return bin_edges
#     670
#
# ~\anaconda3\lib\site-packages\numpy\lib\histograms.py in _get_bin_edges(a, bins, range, weights)
#     394                             "bins is not supported for weighted data")
#     395
# --> 396         first_edge, last_edge = _get_outer_edges(a, range)
#     397
#     398         # truncate the range if needed
#
# ~\anaconda3\lib\site-packages\numpy\lib\histograms.py in _get_outer_edges(a, range)
#     309     if range is not None:
#     310         first_edge, last_edge = range
# --> 311         if first_edge > last_edge:
#     312             raise ValueError(
#     313                 'max must be larger than min in range parameter.')
#
# ValueError: The truth value of an array with more than one element is ambiguous. Use a.any() or a.all()

# %%
x = (np.log(10,1))
x
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_15588/4148037331.py in <module>
# ----> 1 x = (np.log(10,1))
#       2 x
#
# TypeError: return arrays must be of ArrayType

# %% [markdown]
# ## References

# %% [markdown]
# <b id="f2">2</b> https://docs.python.org/3/faq/general.html#what-is-python [↩](#a2)

# %% [markdown]
# <b id="f1">1</b> https://matplotlib.org/ [↩](#a1)

# %% [markdown]
# <b id="f2">2</b> https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.html [↩](#a2)
